# %% [markdown]
# # ACLED data
#
# https://developer.acleddata.com/

# %%
import pandas as pd

# %% [markdown]
# ### API
#
# * json => https://api.acleddata.com/acled/read?key={api_key}&email={email}
# * csv => https://api.acleddata.com/acled/read.csv?key={api_key}&email={email}
# * txt => https://api.acleddata.com/acled/read.txt?key={api_key}&email={email}

# %%
# api_key = 'SKYlSoT7kDai9BCMN!V5'  # Revoked 26-8-2024
api_key = 'T9YSTnpfeSaoc8fWZnPG'
email = 'email@peteranema.nl'

year = 2024
country = 'Netherlands'

url = 'https://api.acleddata.com/acled/read'
url += f'?key={api_key}'
url += f'&email={email}'

url += f'&year={year}'
url += f'&country={country}'

url
# Out:
# 'https://api.acleddata.com/acled/read?key=T9YSTnpfeSaoc8fWZnPG&email=email@peteranema.nl&year=2024&country=Netherlands'

# %% [markdown]
# ### Get the data

# %%
df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv(url)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# ### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   event_id_cnty       260 non-null    object
#  1   event_date          260 non-null    object
#  2   year                260 non-null    int64
#  3   time_precision      260 non-null    int64
#  4   disorder_type       260 non-null    object
#  5   event_type          260 non-null    object
#  6   sub_event_type      260 non-null    object
#  7   actor1              260 non-null    object
#  8   assoc_actor_1       183 non-null    object
#  9   inter1              260 non-null    int64
#  10  actor2              45 non-null     object
#  11  assoc_actor_2       10 non-null     object
#  12  inter2              260 non-null    int64
#  13  interaction         260 non-null    int64
#  14  civilian_targeting  0 non-null      float64
# ...

# %%
df['event_type'].value_counts()
# Out:
# event_type
# Protests                  244
# Riots                      15
# Strategic developments      1
# Name: count, dtype: int64

# %% [markdown]
# ### Analysis

# %%
df_per_day = df.groupby('event_date').size()

# %%
df_per_day
# Out:
# event_date
# 2024-01-05     1
# 2024-01-06     1
# 2024-01-07     2
# 2024-01-08     1
# 2024-01-10     2
#               ..
# 2024-05-13     9
# 2024-05-14     3
# 2024-05-15    10
# 2024-05-16     4
# 2024-05-17     3
# Length: 105, dtype: int64

# %%
df_per_day.plot()
# Out:
# <Axes: xlabel='event_date'>
